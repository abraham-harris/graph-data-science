# %% [markdown]
# # Homework 1
#     Abraham Harris

# %%
import networkx as nx
import network_utilities as nu
import plotting_utilities as pu

# %% [markdown]
# ## 11.

# %%
G = nx.complete_graph(8)
pu.show_graph(G)
pu.show_degree_distribution(G)

# %% [markdown]
# ## 12.

# %%
G = nx.circulant_graph(8, [1])
pu.show_graph(G)
pu.show_degree_distribution(G)

# %% [markdown]
# ## 13.

# %%
G = nx.circulant_graph(8, [1])
pu.show_graph(G)
pu.show_degree_distribution(G)
